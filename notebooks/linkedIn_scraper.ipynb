# %%
# Out:
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs

# %%
import os 

os.chdir('c:/Users/Domen/IronHack/01_projects/IH_final_project_data-jobs')
print(os.getcwd())
# Importing necessary libraries
# Out:
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs

# %%
import winsound
import numpy as np
from bs4 import BeautifulSoup, NavigableString
import requests
from time import sleep
from random import randint
import math
from tqdm import tqdm
import pickle
import pandas as pd
from datetime import date
from datetime import datetime
import json
import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine, text  # for establishing the connection and authentication
import zlib
# Importing necessary libraries

# %%
from src.myModules import scraper_ds as mybib


# %load_ext autoreload
# %autoreload 2
# Importing necessary libraries
# Out:
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs

# %%
print(os.getcwd())
with open("config/config.json", 'r') as f:
    config = json.load(f)
    
temp_data_path = config["temp_data_path"]
webscrap_data_path = config["webscrap_data_path"]   
sound_path = config["sound_path"]

print(temp_data_path)
print(webscrap_data_path)
# Out:
# c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs
# data/temp_data/
# data/webscrap_data/

# %%
soup_file =  'soup_dictV2'
keyword_file = 'keyword_dictV2'
database_file = 'databaseV2'

# %% [markdown]
# ### Import keywords

# %%
keyword_list= ['data_analyst', 'data_engineer', 'business_analyst', 'product_analyst', 'business_intelligence_analyst', 
               'data_scientist', 'machine_learning_engineer', 'ai_engineer',
               'cloud_engineer', 'deep_learning_engineer']
keyword_list
# Out:
# ['data_analyst',
#  'data_engineer',
#  'business_analyst',
#  'product_analyst',
#  'business_intelligence_analyst',
#  'data_scientist',
#  'machine_learning_engineer',
#  'ai_engineer',
#  'cloud_engineer',
#  'deep_learning_engineer']

# %% [markdown]
# ### Scrap Prep
# - connect with MySQL to get id's
# - create empty DataFrame for saving scraping results
# - print results for check

# %%
try:
    with open(f"{webscrap_data_path}{soup_file}.pkl", "rb") as file:
        soup_dict = pickle.load(file)
    with open(f"{temp_data_path}{soup_file}_backup.pkl", "wb") as file:
        pickle.dump(soup_dict, file)
except Exception as e:
    raise ValueError(f"Error occurred: {e} - soup_dict")      
        
try:
    with open(f"{webscrap_data_path}{keyword_file}.pkl", "rb") as file:
        keyword_dict = pickle.load(file)
    with open(f"{temp_data_path}{keyword_file}_backup.pkl", "wb") as file:
        pickle.dump(soup_dict, file) 
except Exception as e:
    raise ValueError(f"Error occurred: {e} - keyword_dict")   

    
scraper_df = mybib.initialize_empty_df()

# %%
print(len(soup_dict))
print(len(keyword_dict))
# Out:
# 14480
# 14480

# %%
print(soup_dict)
id_control = []
for item in soup_dict.keys():
    id_control.append(item)
# Out:
# {'3719620327': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3724233663': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3722456887': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3713133845': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3727896816': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3708490416': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3720365801': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3721905834': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3684585086': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3723986556': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3713809714': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3704916810': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3714114129': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3709621012': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3724707874': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3707596225': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3702244695': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3706774867': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3722170530': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3725024965': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3709672083': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3719405734': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3724264021': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3719996482': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3724262183': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3713487910': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3691406429': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3726368814': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3709394151': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3674598449': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3666792157': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3722005706': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3709323531': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3714672916': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3713886419': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3675386073': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3707908211': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [429]>}, '3717206500': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3715197199': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3725424456': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3708829631': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3713020151': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3710653319': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3726658813': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3717077812': {'scrap_date': datetime.date(2023, 9, 26), 'response': <Response [200]>}, '3710873356': {'scrap_date': datetime.d ...

# %%
id_control
# Out:
# ['3719620327',
#  '3724233663',
#  '3722456887',
#  '3713133845',
#  '3727896816',
#  '3708490416',
#  '3720365801',
#  '3721905834',
#  '3684585086',
#  '3723986556',
#  '3713809714',
#  '3704916810',
#  '3714114129',
#  '3709621012',
#  '3724707874',
#  '3707596225',
#  '3702244695',
#  '3706774867',
#  '3722170530',
#  '3725024965',
#  '3709672083',
#  '3719405734',
#  '3724264021',
#  '3719996482',
#  '3724262183',
#  '3713487910',
#  '3691406429',
#  '3726368814',
#  '3709394151',
#  '3674598449',
#  '3666792157',
#  '3722005706',
#  '3709323531',
#  '3714672916',
#  '3713886419',
#  '3675386073',
#  '3707908211',
#  '3717206500',
#  '3715197199',
#  '3725424456',
#  '3708829631',
#  '3713020151',
#  '3710653319',
#  '3726658813',
#  '3717077812',
#  '3710873356',
#  '3713040768',
#  '3717722594',
#  '3708485850',
#  '3716429919',
#  '3721290067',
#  '3713044156',
#  '3708375784',
#  '3715644103',
#  '3718972779',
#  '3713367502',
#  '3706371923',
#  '3723314893',
#  '3705818750',
#  '3716725469',
#  '3719972463',
#  '3718518774',
#  '3711895078',
#  '3706091445',
#  '3720128757',
#  '3711692443',
#  '3674299855',
#  '3725846617',
#  '3717620304',
#  '3726487430',
#  '3708806075',
#  '3674604294',
#  '3508748216',
#  '3719971767',
#  '3707153912',
#  '3720825257',
#  '3726673965',
#  '3670095589',
#  '3703773720',
#  '3715608872',
#  '3712833846',
#  '3702040565',
#  '3725424540',
#  '3715816443',
#  '3688495290',
#  '3724234849',
#  '3703776281',
#  '3703774500',
#  '3725401052',
#  '3713562755',
#  '3724856558',
#  '3703987720',
#  '3710579783',
#  '3719148389',
#  '3725433237',
#  '3713663034',
#  '3726620136',
#  '3724299884',
#  '3639858057',
#  '3726488148',
#  '3723216034',
#  '3639857095',
#  '3719158930',
#  '3719581219',
#  '3703693100',
#  '3707379301',
#  '3713682733',
#  '3701745744',
#  '3726368827',
#  '3689376257',
#  '3689375546',
#  '3712838158',
#  '3689379010',
#  '3689378048',
#  '3689376259',
#  '3682815660',
#  '3722318545',
#  '3709671201',
#  '3708199864',
#  '3723312092',
#  '3727440110',
#  '3682817497',
#  '3722130060',
#  '3707904901',
#  '3719620264',
#  '3707611341',
#  '3726806050',
#  '3711615935',
#  '3719510217',
#  '3661869596',
#  '3718990271',
#  '3713235511',
#  '3725141252',
#  '3704826510',
#  '3723305936',
#  '3720740547',
#  '3714180455',
#  '3463183538',
#  '2960147876',
#  '3710584368',
#  '3710731234',
#  '3716931560',
#  '3717088518',
#  '3701786506',
#  '3711964211',
#  '3710653394',
#  '3683680523',
#  '3724235228',
#  '3725339804',
#  '3706527233',
#  '3712199176',
#  '3706524406',
#  '3726487442',
#  '3724869613',
#  '3709394164',
#  '3704839708',
#  '3724260319',
#  '3653206016',
#  '3595294011',
#  '3725802433',
#  '3707397167',
#  '3654923234',
#  '3720334419',
#  '3727865510',
#  '3716350873',
#  '3645883252',
#  '3726156014',
#  '3708835101',
#  '3714669730',
#  '3726659787',
#  '3714605709',
#  '3171159430',
#  '3702036995',
#  '3726153214',
#  '3655541769',
#  '3171155942',
#  '3725830101',
#  '3721900429',
#  '3715118684',
#  '3726676524',
#  '3719990979',
#  '3726150466',
#  '3712048785',
#  '3726150489',
#  ...]

# %%
try:
    for key in keyword_list:
        first_url = f"https://www.linkedin.com/jobs/search?keywords={key}&location=Stuttgart%2C%20Baden-W%C3%BCrttemberg%2C%20Germany&geoId=102473731&position=1&pageNum=0"
        key_name = key.replace('%20', " ")
            
        response = requests.get(first_url) # first request for keyword
        response.status_code # 200 status code means OK!
        soup = BeautifulSoup(response.content, "html.parser")
        
        number_of_results = soup.find('span', class_="results-context-header__job-count").text # check number of searching results
        numb = int(number_of_results.replace(",", "").replace("+", ""))

        backend_call_url_list = []
        backend_call_url_list = mybib.create_backend_links(first_url, numb, key_name) # create list with sublinks to select different pages 
        
        
        
        id_array = mybib.get_id_list(backend_call_url_list) # get job id's from all pages
        

        with tqdm(total=len(id_array), desc="Starting") as pbar:
        
            for id in id_array:
                counter = 0
                backupsave = [25, 50, 75, 100, 125, 150, 175, 200, 300] 
                if counter in backupsave:
                    new_dataframe = mybib.export_data(soup_dict, keyword_dict)
                    scraper_df = pd.DataFrame(columns=scraper_df.columns)
                    print("Updated dataframe")
                dynamic_text = f"id {id}" # text for tqdm progress bar status
                pbar.set_description(dynamic_text) # change text
                pbar.update(1)
                
                if str(id) not in id_control:
                    try:
                        
                        response = requests.get(f'https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{id}')
                        wait_time = randint(1,200)
                        sleep(wait_time/1000)
                        
                        dict2 = {}
                        dict2["scrap_date"] = date.today()
                        dict2["response"] = response
                        soup_dict[id] = dict2
                        try:
                            keyword_dict[id].append(key_name)
                        except:
                            keyword_dict[id] = [key_name]


                    except Exception as e:
                        raise ValueError(f"Error occurred: {e} getting data from id {id}")
                        
                else:
                    pbar.set_description(f"Will skip {id} because is already in the dataset.")
                    try:
                        keyword_dict[id].append(key_name)
                    except:
                        keyword_dict[id] = [key_name]
                counter += 1    
        new_dataframe = mybib.export_data(soup_dict, keyword_dict)
        print("\n \n")
except Exception as e:
    winsound.PlaySound(f"{sound_path}alarm3.wav", winsound.SND_FILENAME)
    raise ValueError(f"Error occurred: {e}")
    
winsound.PlaySound(f"{sound_path}alarm3.wav", winsound.SND_FILENAME)
# Out:
# Start creating backend links for data_analyst. Total of found pages: 40
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:40<00:00,  1.00s/it]
# id 3600542315: 100%|█████████████████████████████████████████████████████████████████| 987/987 [08:54<00:00,  1.85it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs\src\myModules\scraper_ds.py:378, in export_data(soup_dict, keyword_dict)
#     371 try:
#     372     # mybib.add_scrapped_df_to_sql_database(new_dataframe, con=engine, if_exists='replace', index=False))
#     373     # display(new_scraper_df.tail(5))
#     374     # new_dataframe = pd.concat([old_df, scrap_df], ignore_index=True)
#     375     # mybib.add_scrapped_df_to_sql_database(Scrap_backup, con=engine, if_exists='replace', index=False))
# --> 378     with open(f"{webscrap_data_path}{soup_file}.pkl", "wb") as file:
#     379         pickle.dump(soup_dict, file=file)
#
# NameError: name 'soup_file' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 70
#      69         counter += 1
# ---> 70 new_dataframe = mybib.export_data(soup_dict, keyword_dict)
#      71 print("\n \n")
#
# File c:\Users\Domen\IronHack\01_projects\IH_final_project_data-jobs\src\myModules\scraper_ds.py:389, in export_data(soup_dict, keyword_dict)
#     387 except Exception as e:
#     388     # Handle any exceptions and provide informative error messages
# --> 389     raise ValueError(f"Error occurred: {e}")
#     390 return
#
# ValueError: Error occurred: name 'soup_file' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 74
#      72 except Exception as e:
#      73     winsound.PlaySound("alarm2.wav", winsound.SND_FILENAME)
# ---> 74     raise ValueError(f"Error occurred: {e}")
#      76 winsound.PlaySound("alarm3.wav", winsound.SND_FILENAME)
#
# ValueError: Error occurred: Error occurred: name 'soup_file' is not defined

# %%
display(len(soup_dict))
display(len(keyword_dict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # display(new_dataframe.shape)
# ----> 2 display(len(soup_dict))
#       3 display(len(keyword_dict))
#
# NameError: name 'soup_dict' is not defined

# %%
new_dataframe['id'].value_counts()

# %%
df_unique = new_dataframe.drop_duplicates(subset=['id'])
df_unique

# %%
with open(f"webscraper/webscrap_data/{database_file}.pkl" , "wb") as f:
    pickle.dump(df_unique, f)

# %%
columns = new_dataframe.columns

for col in columns:
    null = new_dataframe[col].isna().sum()
    print(f"{round(null / len(new_dataframe[col]) * 100,1)}%    {col}:")

# %%
keywords_input = ['Data%20Analyst']
keywords = []

# %%
first_url = f"https://www.linkedin.com/jobs/search?keywords=%7Bkey%7D&location=Berlin%2C%20Berlin%2C%20Germany&locationId=&geoId=106967730&f_TPR=&f_PP=106967730&distance=25&f_JT=F&f_E=2%2C3%2C4&position=1&pageNum=0"

# %%
response = requests.get(f'https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/3717202675')

# %%
soup_dict['3719620327']

# %%
response = soup_dict['3719620327']

soup = BeautifulSoup(response.content, "html.parser")
soup

# %%
soup.find("section",{"class":"show-more-less-html"}).text.strip()

# %%
soup_dict

# %%
soup_dict.keys()

# %%
new_soup_dict = {}

# %%
for key in soup_dict:
    temp = {}
    
    dict2 = {}
    dict2["scrap_date"] = date.today()
    dict2["response"] = soup_dict[key]
    new_soup_dict[key] = dict2

# %%
new_soup_dict

# %%
with open("webscraper/webscrap_data/soup_dict.pkl", "wb") as f:
    pickle.dump(new_soup_dict, f)

# %%
id_list = mybib.get_id_list(backend_call_url_list)

# %%
len(id_list)
